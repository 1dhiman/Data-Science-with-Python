# 20        2                        peugeot 504
# 21        2                        audi 100 ls
# 22        2                           saab 99e
# 23        2                           bmw 2002
# 24        1                        amc gremlin
# 25        1                          ford f250
# 26        1                          chevy c20
# 27        1                         dodge d200
# 28        1                           hi 1200d
# 29        3                       datsun pl510
# ..      ...                                ...
# 170       1           chevrolet cavalier wagon
# 171       1          chevrolet cavalier 2-door
# 172       1         pontiac j2000 se hatchback
# 173       1                     dodge aries se
# 174       1                    pontiac phoenix
# 175       1               ford fairmont futura
# 176       1                     amc concord dl
# 177       2                volkswagen rabbit l
# 178       3                 mazda glc custom l
# 179       3                   mazda glc custom
# 180       1             plymouth horizon miser
# 181       1                     mercury lynx l
# 182       3                   nissan stanza xe
# 183       3                       honda accord
# 184       3                     toyota corolla
# 185       3                        honda civic
# 186       3                 honda civic (auto)
# 187       3                      datsun 310 gx
# 188       1              buick century limited
# 189       1  oldsmobile cutlass ciera (diesel)
# 190       1         chrysler lebaron medallion
# 191       1                     ford granada l
# 192       3                   toyota celica gt
# 193       1                  dodge charger 2.2
# 194       1                   chevrolet camaro
# 195       1                    ford mustang gl
# 196       2                          vw pickup
# 197       1                      dodge rampage
# 198       1                        ford ranger
# 199       1                         chevy s-10
#
# [398 rows x 9 columns]

# %%
# add new column owners
nr_owners = np.random.randint(15000, high=73001, size=398, dtype='l')
nr_owners
# Out:
# array([25843, 18068, 20874, 71891, 47926, 57794, 69989, 19325, 42952,
#        30958, 59279, 20125, 53376, 39335, 36517, 72255, 37341, 68927,
#        66292, 43772, 51344, 69631, 60879, 38425, 72103, 36440, 48714,
#        19014, 37384, 20604, 64888, 31876, 42325, 33036, 55348, 61974,
#        62504, 60489, 15095, 28500, 18401, 40495, 53422, 27756, 20580,
#        61751, 58326, 65645, 30696, 44289, 37059, 63600, 70024, 31730,
#        50223, 43609, 16589, 31154, 56365, 67300, 26039, 16413, 31954,
#        61995, 16877, 18478, 66215, 26234, 15041, 64381, 64686, 65135,
#        64109, 60141, 72765, 64279, 28562, 21063, 46071, 37173, 40488,
#        68176, 43600, 26963, 71161, 30164, 68989, 68743, 61006, 68986,
#        66703, 49580, 33527, 65455, 27250, 16753, 28385, 22732, 66340,
#        48442, 18117, 69407, 30284, 20182, 31878, 55052, 54652, 70994,
#        36657, 22994, 69228, 43935, 23524, 16475, 55884, 15712, 64354,
#        20145, 38263, 50307, 39192, 29401, 48521, 48488, 26998, 16071,
#        19736, 54342, 64579, 46584, 28503, 35747, 47650, 62112, 17590,
#        29944, 59323, 23719, 50616, 51265, 16508, 63103, 58659, 27261,
#        29444, 50552, 39807, 54890, 23462, 59858, 41243, 57344, 44067,
#        60142, 47496, 60433, 24770, 28174, 25810, 52909, 61478, 38635,
#        24709, 64134, 48343, 33794, 70569, 70679, 41465, 28859, 47050,
#        64249, 36921, 35778, 50747, 24119, 19035, 67786, 51212, 71998,
#        24960, 47000, 38127, 52261, 62164, 34854, 52432, 23314, 48546,
#        41334, 18106, 65662, 15292, 30711, 39366, 68959, 70144, 32009,
#        51910, 46952, 53771, 69123, 25814, 56873, 58171, 69045, 30236,
#        51014, 61716, 25193, 48797, 54639, 36840, 17248, 60012, 55425,
#        69263, 18427, 20451, 36195, 36388, 63079, 24030, 71199, 59084,
#        62485, 16157, 45177, 40254, 58146, 45906, 32922, 42040, 64409,
#        34735, 19076, 34952, 70750, 69926, 61301, 51422, 57534, 48083,
#        72343, 67838, 19025, 21422, 30303, 30972, 31107, 46110, 19755,
#        36800, 57857, 70655, 44241, 68972, 39822, 37581, 51013, 62062,
#        50117, 42876, 45820, 48755, 30339, 26845, 20369, 59813, 27753,
#        56230, 27072, 37346, 29906, 49626, 46543, 54767, 21891, 30991,
#        15631, 43396, 37647, 16930, 67591, 63920, 26750, 27459, 63103,
#        63638, 49365, 26744, 17328, 70694, 29824, 18716, 41545, 62870,
#        63402, 29626, 67646, 28058, 39951, 42540, 24011, 46668, 55509,
#        47286, 34720, 15660, 68052, 32860, 68901, 31379, 69767, 48502,
#        48310, 19350, 25167, 19435, 18273, 71362, 61937, 21725, 68048,
#        44588, 41801, 44072, 46635, 23392, 61099, 15004, 59138, 56553,
#        55061, 15648, 55328, 30223, 32055, 52083, 18672, 23273, 62342,
#        35034, 61253, 43447, 38027, 37607, 34211, 53945, 16044, 48815,
#        46489, 54532, 29452, 44227, 50462, 39463, 58576, 17368, 59029,
#        48239, 56069, 26559, 33921, 30395, 32109, 41279, 51125, 68241,
#        65328, 69302, 27854, 18162, 61750, 62894, 42483, 27681, 56642,
#        27700, 72724, 58042, 19861, 25354, 15560, 23862, 51797, 40472,
#        28361, 66989, 43544, 67514, 70366, 25546, 21832, 36855, 24166,
#        68966, 39091])

# %%
cars['owners'] = nr_owners
cars.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin              car  owners
# 195       1  ford mustang gl   21832
# 196       2        vw pickup   36855
# 197       1    dodge rampage   24166
# 198       1      ford ranger   68966
# 199       1       chevy s-10   39091

# %% [markdown]
# # 2. Fictional Names

# %%
raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

data1 = pd.DataFrame(raw_data_1, columns = ['subject_id', 'first_name', 'last_name'])
data2 = pd.DataFrame(raw_data_2, columns = ['subject_id', 'first_name', 'last_name'])
data3 = pd.DataFrame(raw_data_3, columns = ['subject_id','test_id'])

data3
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %%
# join 2 dfs along rows 
all_data = pd.concat([data1, data2])
all_data
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
# join along columns
all_data_col = pd.concat([data1, data2], axis=1)
all_data_col
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 0          1       Alex  Anderson          4      Billy    Bonder
# 1          2        Amy  Ackerman          5      Brian     Black
# 2          3      Allen       Ali          6       Bran   Balwner
# 3          4      Alice      Aoni          7      Bryce     Brice
# 4          5     Ayoung   Atiches          8      Betty    Btisan

# %%
pd.merge(all_data, data3, on='subject_id')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15

# %%
# Merge only the data that has the same 'subject_id' on both data1 and data2
pd.merge(data1, data2, on='subject_id', how='inner')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black

# %%
pd.merge(data1, data2, on='subject_id', how='outer')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brian       Black
# 5          6          NaN         NaN         Bran     Balwner
# 6          7          NaN         NaN        Bryce       Brice
# 7          8          NaN         NaN        Betty      Btisan

# %% [markdown]
# # 3. Housing Market

# %% [markdown]
# Create 3 differents Series, each of length 100, as follows:
#
# * The first a random number from 1 to 4
# * The second a random number from 1 to 3
# * The third a random number from 10,000 to 30,000

# %%
s1 = pd.Series(np.random.randint(1, high=5, size=100, dtype='l'))
s2 = pd.Series(np.random.randint(1, high=4, size=100, dtype='l'))
s3 = pd.Series(np.random.randint(10000, high=30001, size=100, dtype='l'))

# %%
housemkt = pd.concat([s1, s2, s3], axis=1)
housemkt.tail()
# Out:
#     0  1      2
# 95  1  1  26156
# 96  1  2  22040
# 97  4  3  13726
# 98  4  1  15546
# 99  2  1  26982

# %%
housemkt.rename(columns = {0: 'bedrs', 1: 'bathrs', 2: 'price_sqr_meter'}, inplace=True)
housemkt.tail()
# Out:
#     bedrs  bathrs  price_sqr_meter
# 95      1       1            26156
# 96      1       2            22040
# 97      4       3            13726
# 98      4       1            15546
# 99      2       1            26982

# %%
# join concat the values
bigcolumn = pd.concat([s1, s2, s3], axis=0)

# it is still a Series, so we need to transform it to a DataFrame
bigcolumn = bigcolumn.to_frame()
print (type(bigcolumn))

print("Length of dataframe: ",len(bigcolumn))

bigcolumn.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Length of dataframe:  300
#         0
# 95  26156
# 96  22040
# 97  13726
# 98  15546
# 99  26982

# %%
bigcolumn.reset_index(drop=True, inplace=True)
bigcolumn.tail()
# Out:
#          0
# 295  26156
# 296  22040
# 297  13726
# 298  15546
# 299  26982
